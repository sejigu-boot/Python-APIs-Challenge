# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
# Here is summary of the observations:
# 1. The plot for Latitude vs. Temperature shows that the data include more cities from around the equator and the northern hemisphere. For cities further in the right side of 0 latitude (or northern hemisphere), the max temprature dropped low.
#
# 2. The plot for Latitude vs. Humidity shows higher humudity in cities around the equator (or 0 latitude) and around latitude between 45 and 65 degree. The data seems skewed towards the northern hemisphere, as more cities were from that hemisphere.
#
# 3. Latitude vs. Wind Speed Plot shows that the highest % of cloud is concentrated around 0 degree latitude followed by 40-60 deree in the northern hemisphere, what the data appears to skewed.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests, datetime
import json


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#cities and lattitudes and longitudes
cities = []
lats_lngs = []

lats = np.random.uniform(low=-90, high=90, size=2500)
lngs = np.random.uniform(low=-180, high=180, size=2500)
lats_lngs = zip(lats,lngs)

# %%
for lat_lng in lats_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # check if city is unique, then add to cities list
    if city not in cities:
        cities.append(city)
len(cities)
# convert to dataframe
city_df = pd.DataFrame(cities)
city_df.columns = ["City"]
city_df.head()
# Out:
#              City
# 0      rio grande
# 1         salalah
# 2  saint-philippe
# 3       busselton
# 4    saint george

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities[0]
api_key
# Out:
# 'bd3384ff64622a378c15cb4d5755d04f'

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + api_key + "&q=" + cities[0]

#testing connection
response = requests.get(query_url)

weather_json = response.json()

print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'coord': {'lon': -52.1, 'lat': -32.03}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 292.13, 'pressure': 1011, 'humidity': 93, 'temp_min': 292.13, 'temp_max': 292.13, 'sea_level': 1011, 'grnd_level': 1010}, 'wind': {'speed': 6.07, 'deg': 97}, 'rain': {'3h': 2}, 'clouds': {'all': 100}, 'dt': 1572401027, 'sys': {'country': 'BR', 'sunrise': 1572338020, 'sunset': 1572385824}, 'timezone': -10800, 'id': 3451138, 'name': 'Rio Grande', 'cod': 200}.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dataframe to hold all values
weather_df = pd.DataFrame(columns = ["City","Country","Lat","Lng","Date","Temperature","Max_Temperature",
                                    "Min_Temperature","Humidity","Cloudiness","Wind Speed"])

print(f'Beginning Data Retrieval')
print(f'------------------------------')
for index, city in city_df.iterrows():

   city_name = city['City']

   #assemble url and make API request
   query_url = url + "appid=" + api_key + "&q=" + city_name
   response = requests.get(query_url).json()

   try:
       print(f'Processing Record {index} of Set 1 | ' + city_name)

       if response['main']['temp'] != '':
           #saving to a dataframe
           weather_df.loc[index,'City'] = city_name
           weather_df.loc[index,'Country'] = response['sys']['country']
           weather_df.loc[index,'Temperature'] = response['main']['temp']
           weather_df.loc[index,'Max_Temperature'] = response['main']['temp_max']
           weather_df.loc[index,'Min_Temperature'] = response['main']['temp_min']
           weather_df.loc[index,'Lat'] = response['coord']['lat']
           weather_df.loc[index,'Lng'] = response['coord']['lon']
           weather_df.loc[index,'Date'] = response['dt']
           weather_df.loc[index,'Humidity'] = response['main']['humidity']
           weather_df.loc[index,'Cloudiness'] = response['clouds']['all']
           weather_df.loc[index,'Wind Speed'] = response['wind']['speed']
       else:
           print(f'City not found. Skipping...')
   except (KeyError,IndexError):
       print(f'City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 0 of Set 1 | rio grande
# Processing Record 1 of Set 1 | salalah
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | port-cartier
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | avera
# Processing Record 9 of Set 1 | mozhga
# Processing Record 10 of Set 1 | vao
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | pasni
# Processing Record 19 of Set 1 | borgen
# Processing Record 20 of Set 1 | kenai
# Processing Record 21 of Set 1 | adoni
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | timbiqui
# Processing Record 24 of Set 1 | bom jardim
# Processing Record 25 of Set 1 | margate
# Processing Record 26 of Set 1 | beyneu
# Processing Record 27 of Set 1 | bosaso
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | sao jose da coroa grande
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | san quintin
# Processing Record 38 of Set 1 | hofn
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | coquimbo
# Processing Record 41 of Set 1 | sassandra
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | haines junction
# Processing Record 45 of Set 1 | meulaboh
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | komsomolskiy
# Processing Record 50 of Set 1 | fortuna
# Processing Record 51 of Set 1 | pisco
# Processing Record 52 of Set 1 | east london
# Processing Record 53 of Set 1 | great yarmouth
# Processing Record 54 of Set 1 | winton
# Processing Record 55 of Set 1 | westport
# Processing Record 56 of Set 1 | nanortalik
# Processing Record 57 of Set 1 | nogliki
# Processing Record 58 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 59 of Set 1 | lompoc
# Processing Record 60 of Set 1 | puerto ayora
# Processing Record 61 of Set 1 | sitka
# Processing Record 62 of Set 1 | grindavik
# Processing Record 63 of Set 1 | pacific grove
# Processing Record 64 of Set 1 | qaanaaq
# Processing Record 65 of Set 1 | punta arenas
# Processing Record 66 of Set 1 | chokurdakh
# Processing Record 67 of Set 1 | prince rupert
# Processing Record 68 of Set 1 | albany
# Processing Record 69 of Set 1 | hobart
# Processing Record 70 of Set 1 | sayyan
# Processing Record 71 of Set 1 | mao
# Processing Record 72 of Set 1 | mataura
# Processing Record 73 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 74 of Set 1 | visby
# Processing Record 75 of Set 1 | ahipara
# Processing Record 76 of Set 1 | sorland
# Processing Record 77 of Set 1 | abbeville
# Processing Record 78 of Set 1 | kaohsiung
# Processing Record 79 of Set 1 | tuatapere
# Processing Record 80 of Set 1 | hilo
# Processing Record 81 of Set 1 | maralal
# Processing Record 82 of Set 1 | snezhnogorsk
# Processing Record 83 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 84 of Set 1 | khatanga
# Processing Record 85 of Set 1 | bredasdorp
# Processing Record 86 of Set 1 | khasan
# Processing Record 87 of Set 1 | aklavik
# Processing Record 88 of Set 1 | codrington
# Processing Record 89 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 90 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 91 of Set 1 | aksu
# Processing Record 92 of Set 1 | mahebourg
# Processing Record 93 of Set 1 | new norfolk
# Processing Record 94 of Set 1 | lebu
# Processing Record 95 of Set 1 | jamestown
# Processing Record 96 of Set 1 | dunedin
# Processing Record 97 of Set 1 | ustyuzhna
# Processing Record 98 of Set 1 | victor harbor
# Processing Record 99 of Set 1 | laguna
# Processing Record 100 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 101 of Set 1 | viedma
# Processing Record 102 of Set 1 | carutapera
# Processing Record 103 of Set 1 | cabo san lucas
# Processing Record 104 of Set 1 | hasaki
# Processing Record 105 of Set 1 | barrow
# Processing Record 106 of Set 1 | saldanha
# Processing Record 107 of Set 1 | ugleuralskiy
# Processing Record 108 of Set 1 | castro
# Processing Record 109 of Set 1 | sembabule
# Processing Record 110 of Set 1 | kununurra
# Processing Record 111 of Set 1 | kavaratti
# Processing Record 112 of Set 1 | kilindoni
# Processing Record 113 of Set 1 | yadrin
# Processing Record 114 of Set 1 | bodh gaya
# Processing Record 115 of Set 1 | yellowknife
# Processing Record 116 of Set 1 | iqaluit
# Processing Record 117 of Set 1 | korla
# City not found. Skipping...
# Processing Record 118 of Set 1 | illapel
# Processing Record 119 of Set 1 | ratanpur
# Processing Record 120 of Set 1 | klaksvik
# Processing Record 121 of Set 1 | thinadhoo
# Processing Record 122 of Set 1 | victoria
# Processing Record 123 of Set 1 | norman wells
# Processing Record 124 of Set 1 | blytheville
# Processing Record 125 of Set 1 | jumla
# Processing Record 126 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 127 of Set 1 | bilibino
# Processing Record 128 of Set 1 | oksfjord
# Processing Record 129 of Set 1 | burica
# City not found. Skipping...
# Processing Record 130 of Set 1 | lianzhou
# Processing Record 131 of Set 1 | miri
# Processing Record 132 of Set 1 | vanimo
# Processing Record 133 of Set 1 | nelson bay
# Processing Record 134 of Set 1 | dong hoi
# Processing Record 135 of Set 1 | longyearbyen
# Processing Record 136 of Set 1 | carnarvon
# Processing Record 137 of Set 1 | pangnirtung
# Processing Record 138 of Set 1 | port elizabeth
# Processing Record 139 of Set 1 | ribeira grande
# Processing Record 140 of Set 1 | san cristobal
# Processing Record 141 of Set 1 | pafos
# City not found. Skipping...
# Processing Record 142 of Set 1 | fairbanks
# Processing Record 143 of Set 1 | nome
# Processing Record 144 of Set 1 | goundam
# Processing Record 145 of Set 1 | nokaneng
# Processing Record 146 of Set 1 | capitao poco
# Processing Record 147 of Set 1 | lavrentiya
# Processing Record 148 of Set 1 | dilla
# Processing Record 149 of Set 1 | scottsbluff
# Processing Record 150 of Set 1 | naze
# Processing Record 151 of Set 1 | nortelandia
# Processing Record 152 of Set 1 | hay river
# Processing Record 153 of Set 1 | guerrero negro
# Processing Record 154 of Set 1 | clyde river
# Processing Record 155 of Set 1 | bethel
# Processing Record 156 of Set 1 | tommot
# Processing Record 157 of Set 1 | carikar
# City not found. Skipping...
# Processing Record 158 of Set 1 | broome
# Processing Record 159 of Set 1 | kapaa
# Processing Record 160 of Set 1 | verkhnyaya sysert
# Processing Record 161 of Set 1 | constitucion
# Processing Record 162 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 163 of Set 1 | hobyo
# Processing Record 164 of Set 1 | bertoua
# Processing Record 165 of Set 1 | kremenchuk
# Processing Record 166 of Set 1 | pevek
# Processing Record 167 of Set 1 | marrakesh
# Processing Record 168 of Set 1 | tuktoyaktuk
# Processing Record 169 of Set 1 | tevriz
# Processing Record 170 of Set 1 | milicz
# Processing Record 171 of Set 1 | tonder
# Processing Record 172 of Set 1 | cukai
# Processing Record 173 of Set 1 | warmbad
# Processing Record 174 of Set 1 | hellvik
# Processing Record 175 of Set 1 | bathsheba
# Processing Record 176 of Set 1 | cudahy
# Processing Record 177 of Set 1 | oak ridge
# Processing Record 178 of Set 1 | lehi
# Processing Record 179 of Set 1 | leningradskiy
# Processing Record 180 of Set 1 | loukhi
# Processing Record 181 of Set 1 | ornes
# Processing Record 182 of Set 1 | tiksi
# Processing Record 183 of Set 1 | udachnyy
# Processing Record 184 of Set 1 | macomb
# Processing Record 185 of Set 1 | faanui
# Processing Record 186 of Set 1 | kovur
# Processing Record 187 of Set 1 | yumen
# Processing Record 188 of Set 1 | castanos
# Processing Record 189 of Set 1 | okhotsk
# Processing Record 190 of Set 1 | buraydah
# Processing Record 191 of Set 1 | ilulissat
# Processing Record 192 of Set 1 | port macquarie
# Processing Record 193 of Set 1 | namibe
# Processing Record 194 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 195 of Set 1 | touros
# Processing Record 196 of Set 1 | gaspe
# Processing Record 197 of Set 1 | comodoro rivadavia
# Processing Record 198 of Set 1 | pitimbu
# Processing Record 199 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 200 of Set 1 | dali
# Processing Record 201 of Set 1 | andenes
# City not found. Skipping...
# Processing Record 202 of Set 1 | praia da vitoria
# Processing Record 203 of Set 1 | hithadhoo
# Processing Record 204 of Set 1 | san ramon
# Processing Record 205 of Set 1 | skibbereen
# Processing Record 206 of Set 1 | slavsk
# Processing Record 207 of Set 1 | paamiut
# Processing Record 208 of Set 1 | oranjemund
# Processing Record 209 of Set 1 | adre
# Processing Record 210 of Set 1 | puerto del rosario
# Processing Record 211 of Set 1 | georgetown
# Processing Record 212 of Set 1 | thompson
# Processing Record 213 of Set 1 | atar
# Processing Record 214 of Set 1 | vila velha
# Processing Record 215 of Set 1 | morehead
# Processing Record 216 of Set 1 | talnakh
# Processing Record 217 of Set 1 | orocue
# Processing Record 218 of Set 1 | ribeira brava
# Processing Record 219 of Set 1 | bereda
# Processing Record 220 of Set 1 | kedrovyy
# Processing Record 221 of Set 1 | manjacaze
# Processing Record 222 of Set 1 | nantucket
# Processing Record 223 of Set 1 | mount gambier
# Processing Record 224 of Set 1 | sajanan
# Processing Record 225 of Set 1 | dolores
# Processing Record 226 of Set 1 | ketchikan
# Processing Record 227 of Set 1 | olafsvik
# City not found. Skipping...
# Processing Record 228 of Set 1 | hamilton
# Processing Record 229 of Set 1 | cazaje
# City not found. Skipping...
# Processing Record 230 of Set 1 | lorengau
# Processing Record 231 of Set 1 | cherskiy
# Processing Record 232 of Set 1 | torbay
# Processing Record 233 of Set 1 | bokoro
# City not found. Skipping...
# Processing Record 234 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 235 of Set 1 | ballina
# Processing Record 236 of Set 1 | atasu
# Processing Record 237 of Set 1 | yingkou
# Processing Record 238 of Set 1 | roald
# Processing Record 239 of Set 1 | karpathos
# Processing Record 240 of Set 1 | neyshabur
# Processing Record 241 of Set 1 | deputatskiy
# Processing Record 242 of Set 1 | asfi
# City not found. Skipping...
# Processing Record 243 of Set 1 | waipawa
# Processing Record 244 of Set 1 | kemin
# Processing Record 245 of Set 1 | faya
# Processing Record 246 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 247 of Set 1 | port blair
# Processing Record 248 of Set 1 | kisii
# Processing Record 249 of Set 1 | anloga
# Processing Record 250 of Set 1 | camargo
# Processing Record 251 of Set 1 | geraldton
# Processing Record 252 of Set 1 | saint-joseph
# Processing Record 253 of Set 1 | namatanai
# Processing Record 254 of Set 1 | tasiilaq
# Processing Record 255 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 256 of Set 1 | lasa
# Processing Record 257 of Set 1 | umm kaddadah
# Processing Record 258 of Set 1 | tevaitoa
# Processing Record 259 of Set 1 | tshikapa
# Processing Record 260 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 261 of Set 1 | grand gaube
# Processing Record 262 of Set 1 | beruwala
# Processing Record 263 of Set 1 | scarborough
# Processing Record 264 of Set 1 | severo-kurilsk
# Processing Record 265 of Set 1 | dawson
# Processing Record 266 of Set 1 | mount darwin
# Processing Record 267 of Set 1 | arequipa
# Processing Record 268 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 269 of Set 1 | marzuq
# Processing Record 270 of Set 1 | kaitangata
# Processing Record 271 of Set 1 | rudnichnyy
# Processing Record 272 of Set 1 | manado
# Processing Record 273 of Set 1 | hauterive
# Processing Record 274 of Set 1 | yei
# City not found. Skipping...
# Processing Record 275 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 276 of Set 1 | puerto madryn
# Processing Record 277 of Set 1 | aswan
# Processing Record 278 of Set 1 | zheleznodorozhnyy
# Processing Record 279 of Set 1 | bonthe
# Processing Record 280 of Set 1 | kahului
# Processing Record 281 of Set 1 | sistranda
# Processing Record 282 of Set 1 | havoysund
# Processing Record 283 of Set 1 | mitsamiouli
# Processing Record 284 of Set 1 | luderitz
# Processing Record 285 of Set 1 | oktyabrskiy
# Processing Record 286 of Set 1 | haicheng
# Processing Record 287 of Set 1 | terrace
# Processing Record 288 of Set 1 | yulara
# Processing Record 289 of Set 1 | port-gentil
# Processing Record 290 of Set 1 | henties bay
# Processing Record 291 of Set 1 | hrebinka
# Processing Record 292 of Set 1 | chunoyar
# Processing Record 293 of Set 1 | cairo
# Processing Record 294 of Set 1 | panji
# Processing Record 295 of Set 1 | kresek
# Processing Record 296 of Set 1 | husavik
# Processing Record 297 of Set 1 | saquena
# Processing Record 298 of Set 1 | coihaique
# Processing Record 299 of Set 1 | bardiyah
# City not found. Skipping...
# Processing Record 300 of Set 1 | katsuura
# Processing Record 301 of Set 1 | narsaq
# Processing Record 302 of Set 1 | kamina
# Processing Record 303 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 304 of Set 1 | chupei
# City not found. Skipping...
# Processing Record 305 of Set 1 | melbu
# Processing Record 306 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 307 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 308 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 309 of Set 1 | kabwe
# Processing Record 310 of Set 1 | lake havasu city
# Processing Record 311 of Set 1 | gat
# Processing Record 312 of Set 1 | ambatofinandrahana
# Processing Record 313 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 314 of Set 1 | mount isa
# Processing Record 315 of Set 1 | kaeo
# Processing Record 316 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 317 of Set 1 | kabare
# Processing Record 318 of Set 1 | kyaiklat
# Processing Record 319 of Set 1 | provideniya
# Processing Record 320 of Set 1 | baculin
# Processing Record 321 of Set 1 | walvis bay
# Processing Record 322 of Set 1 | kavieng
# Processing Record 323 of Set 1 | mokobeng
# Processing Record 324 of Set 1 | half moon bay
# Processing Record 325 of Set 1 | uthal
# Processing Record 326 of Set 1 | gigmoto
# Processing Record 327 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 328 of Set 1 | tual
# Processing Record 329 of Set 1 | wuwei
# Processing Record 330 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 331 of Set 1 | qena
# Processing Record 332 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 333 of Set 1 | monrovia
# Processing Record 334 of Set 1 | kovdor
# Processing Record 335 of Set 1 | kimbe
# Processing Record 336 of Set 1 | kollam
# Processing Record 337 of Set 1 | san alberto
# Processing Record 338 of Set 1 | necochea
# Processing Record 339 of Set 1 | mayor pablo lagerenza
# Processing Record 340 of Set 1 | manokwari
# Processing Record 341 of Set 1 | opuwo
# Processing Record 342 of Set 1 | soyo
# Processing Record 343 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 344 of Set 1 | grand-santi
# Processing Record 345 of Set 1 | consuegra
# Processing Record 346 of Set 1 | turbat
# Processing Record 347 of Set 1 | caravelas
# Processing Record 348 of Set 1 | dingle
# Processing Record 349 of Set 1 | puerto penasco
# Processing Record 350 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 351 of Set 1 | valparai
# Processing Record 352 of Set 1 | kysyl-syr
# Processing Record 353 of Set 1 | masvingo
# Processing Record 354 of Set 1 | mezen
# Processing Record 355 of Set 1 | san luis
# Processing Record 356 of Set 1 | ocampo
# Processing Record 357 of Set 1 | natal
# Processing Record 358 of Set 1 | nisia floresta
# Processing Record 359 of Set 1 | selkirk
# Processing Record 360 of Set 1 | ossora
# Processing Record 361 of Set 1 | ust-kuyga
# Processing Record 362 of Set 1 | ust-tsilma
# Processing Record 363 of Set 1 | xuanzhou
# Processing Record 364 of Set 1 | krasnyy chikoy
# Processing Record 365 of Set 1 | skelleftea
# Processing Record 366 of Set 1 | ust-kulom
# Processing Record 367 of Set 1 | svetlaya
# Processing Record 368 of Set 1 | owando
# Processing Record 369 of Set 1 | allapalli
# Processing Record 370 of Set 1 | ayios nikolaos
# Processing Record 371 of Set 1 | rafaela
# Processing Record 372 of Set 1 | gizo
# Processing Record 373 of Set 1 | hammerfest
# Processing Record 374 of Set 1 | mandalgovi
# Processing Record 375 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 376 of Set 1 | phalodi
# Processing Record 377 of Set 1 | tomatlan
# Processing Record 378 of Set 1 | serowe
# Processing Record 379 of Set 1 | palanca
# Processing Record 380 of Set 1 | sembe
# City not found. Skipping...
# Processing Record 381 of Set 1 | san patricio
# Processing Record 382 of Set 1 | brae
# Processing Record 383 of Set 1 | goya
# Processing Record 384 of Set 1 | griffith
# Processing Record 385 of Set 1 | baracoa
# Processing Record 386 of Set 1 | patitirion
# Processing Record 387 of Set 1 | tuy hoa
# Processing Record 388 of Set 1 | sovetskiy
# Processing Record 389 of Set 1 | valparaiso
# Processing Record 390 of Set 1 | chuy
# Processing Record 391 of Set 1 | kumba
# Processing Record 392 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 393 of Set 1 | los llanos de aridane
# Processing Record 394 of Set 1 | montalvo
# Processing Record 395 of Set 1 | punta alta
# Processing Record 396 of Set 1 | batemans bay
# Processing Record 397 of Set 1 | garden city
# Processing Record 398 of Set 1 | ambon
# Processing Record 399 of Set 1 | kangaatsiaq
# Processing Record 400 of Set 1 | manadhoo
# Processing Record 401 of Set 1 | kandrian
# Processing Record 402 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 403 of Set 1 | dera ghazi khan
# Processing Record 404 of Set 1 | valencia
# Processing Record 405 of Set 1 | asau
# City not found. Skipping...
# Processing Record 406 of Set 1 | marsa matruh
# Processing Record 407 of Set 1 | japura
# Processing Record 408 of Set 1 | minusio
# Processing Record 409 of Set 1 | cayenne
# Processing Record 410 of Set 1 | selma
# Processing Record 411 of Set 1 | sampit
# Processing Record 412 of Set 1 | atambua
# Processing Record 413 of Set 1 | ishigaki
# Processing Record 414 of Set 1 | port moresby
# Processing Record 415 of Set 1 | kerman
# Processing Record 416 of Set 1 | finschhafen
# Processing Record 417 of Set 1 | salinopolis
# Processing Record 418 of Set 1 | babstovo
# Processing Record 419 of Set 1 | bowling green
# Processing Record 420 of Set 1 | sur
# Processing Record 421 of Set 1 | juegang
# Processing Record 422 of Set 1 | luau
# Processing Record 423 of Set 1 | salamanca
# Processing Record 424 of Set 1 | ostersund
# Processing Record 425 of Set 1 | thasra
# Processing Record 426 of Set 1 | pombas
# Processing Record 427 of Set 1 | lazurne
# Processing Record 428 of Set 1 | cabedelo
# Processing Record 429 of Set 1 | kirakira
# Processing Record 430 of Set 1 | bahar
# Processing Record 431 of Set 1 | sibolga
# Processing Record 432 of Set 1 | alikalia
# Processing Record 433 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 434 of Set 1 | pangody
# Processing Record 435 of Set 1 | aykhal
# Processing Record 436 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 437 of Set 1 | panzhihua
# Processing Record 438 of Set 1 | iquitos
# Processing Record 439 of Set 1 | alofi
# Processing Record 440 of Set 1 | makat
# Processing Record 441 of Set 1 | tiznit
# Processing Record 442 of Set 1 | gopalpur
# Processing Record 443 of Set 1 | novikovo
# Processing Record 444 of Set 1 | sidi bu zayd
# City not found. Skipping...
# Processing Record 445 of Set 1 | kuito
# Processing Record 446 of Set 1 | sao filipe
# Processing Record 447 of Set 1 | the valley
# Processing Record 448 of Set 1 | portland
# Processing Record 449 of Set 1 | santa elena
# Processing Record 450 of Set 1 | novaya maka
# Processing Record 451 of Set 1 | san miguel
# Processing Record 452 of Set 1 | maniitsoq
# Processing Record 453 of Set 1 | souillac
# Processing Record 454 of Set 1 | neuquen
# Processing Record 455 of Set 1 | santa luzia
# Processing Record 456 of Set 1 | shushtar
# Processing Record 457 of Set 1 | bitung
# Processing Record 458 of Set 1 | sungaipenuh
# Processing Record 459 of Set 1 | kalmunai
# Processing Record 460 of Set 1 | cauquenes
# Processing Record 461 of Set 1 | pineville
# Processing Record 462 of Set 1 | qasigiannguit
# Processing Record 463 of Set 1 | toppenish
# Processing Record 464 of Set 1 | mountain home
# Processing Record 465 of Set 1 | abu dhabi
# Processing Record 466 of Set 1 | mosquera
# Processing Record 467 of Set 1 | itatiaia
# Processing Record 468 of Set 1 | hervey bay
# Processing Record 469 of Set 1 | the pas
# Processing Record 470 of Set 1 | vila franca do campo
# Processing Record 471 of Set 1 | tovuz
# Processing Record 472 of Set 1 | mnogovershinnyy
# Processing Record 473 of Set 1 | weinsberg
# Processing Record 474 of Set 1 | tucupita
# Processing Record 475 of Set 1 | juneau
# Processing Record 476 of Set 1 | tamandare
# Processing Record 477 of Set 1 | yangambi
# Processing Record 478 of Set 1 | nakanojo
# Processing Record 479 of Set 1 | honningsvag
# Processing Record 480 of Set 1 | smithers
# Processing Record 481 of Set 1 | morgan city
# Processing Record 482 of Set 1 | marienburg
# Processing Record 483 of Set 1 | mehamn
# Processing Record 484 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 485 of Set 1 | kayerkan
# Processing Record 486 of Set 1 | lubao
# Processing Record 487 of Set 1 | bitkine
# Processing Record 488 of Set 1 | kapchorwa
# Processing Record 489 of Set 1 | valjevo
# Processing Record 490 of Set 1 | gorey
# Processing Record 491 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 492 of Set 1 | shimoda
# Processing Record 493 of Set 1 | mabaruma
# Processing Record 494 of Set 1 | herat
# Processing Record 495 of Set 1 | seoul
# Processing Record 496 of Set 1 | aloleng
# Processing Record 497 of Set 1 | ciudad real
# Processing Record 498 of Set 1 | la asuncion
# Processing Record 499 of Set 1 | kloulklubed
# Processing Record 500 of Set 1 | churapcha
# Processing Record 501 of Set 1 | yabelo
# Processing Record 502 of Set 1 | jinxiang
# Processing Record 503 of Set 1 | sarankhola
# Processing Record 504 of Set 1 | sabzevar
# Processing Record 505 of Set 1 | marawi
# Processing Record 506 of Set 1 | alice springs
# Processing Record 507 of Set 1 | eureka
# Processing Record 508 of Set 1 | moose factory
# Processing Record 509 of Set 1 | taywarah
# Processing Record 510 of Set 1 | muros
# Processing Record 511 of Set 1 | lagoa
# Processing Record 512 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 513 of Set 1 | riverton
# Processing Record 514 of Set 1 | berekum
# Processing Record 515 of Set 1 | lakinsk
# Processing Record 516 of Set 1 | nara
# Processing Record 517 of Set 1 | calafell
# Processing Record 518 of Set 1 | ranong
# Processing Record 519 of Set 1 | linhares
# Processing Record 520 of Set 1 | iralaya
# Processing Record 521 of Set 1 | loiza
# Processing Record 522 of Set 1 | wewak
# Processing Record 523 of Set 1 | novyy svit
# Processing Record 524 of Set 1 | rongai
# Processing Record 525 of Set 1 | sterlibashevo
# Processing Record 526 of Set 1 | buon me thuot
# City not found. Skipping...
# Processing Record 527 of Set 1 | le vauclin
# Processing Record 528 of Set 1 | saint-prosper
# Processing Record 529 of Set 1 | ingham
# Processing Record 530 of Set 1 | new amsterdam
# Processing Record 531 of Set 1 | evensk
# Processing Record 532 of Set 1 | gandajika
# Processing Record 533 of Set 1 | townsville
# Processing Record 534 of Set 1 | sulangan
# Processing Record 535 of Set 1 | moses lake
# Processing Record 536 of Set 1 | yuci
# Processing Record 537 of Set 1 | mamou
# Processing Record 538 of Set 1 | ushtobe
# Processing Record 539 of Set 1 | polovinnoye
# Processing Record 540 of Set 1 | sao joao da barra
# Processing Record 541 of Set 1 | santa maria
# Processing Record 542 of Set 1 | baraya
# Processing Record 543 of Set 1 | daru
# Processing Record 544 of Set 1 | tura
# Processing Record 545 of Set 1 | cervo
# Processing Record 546 of Set 1 | sanem
# Processing Record 547 of Set 1 | thurso
# Processing Record 548 of Set 1 | itabera
# Processing Record 549 of Set 1 | zhaotong
# Processing Record 550 of Set 1 | nenjiang
# Processing Record 551 of Set 1 | raga
# City not found. Skipping...
# Processing Record 552 of Set 1 | gondanglegi
# Processing Record 553 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 554 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 555 of Set 1 | grand junction
# Processing Record 556 of Set 1 | rio gallegos
# Processing Record 557 of Set 1 | derzhavinsk
# Processing Record 558 of Set 1 | concord
# Processing Record 559 of Set 1 | lakes entrance
# Processing Record 560 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 561 of Set 1 | qaqortoq
# Processing Record 562 of Set 1 | yuncheng
# Processing Record 563 of Set 1 | teluk nibung
# City not found. Skipping...
# Processing Record 564 of Set 1 | hearst
# Processing Record 565 of Set 1 | maputo
# Processing Record 566 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 567 of Set 1 | dhidhdhoo
# Processing Record 568 of Set 1 | sangar
# Processing Record 569 of Set 1 | abonnema
# Processing Record 570 of Set 1 | mouzakion
# City not found. Skipping...
# Processing Record 571 of Set 1 | sisimiut
# Processing Record 572 of Set 1 | lumsden
# Processing Record 573 of Set 1 | merauke
# Processing Record 574 of Set 1 | pokhara
# Processing Record 575 of Set 1 | rudnogorsk
# Processing Record 576 of Set 1 | bar harbor
# Processing Record 577 of Set 1 | richards bay
# Processing Record 578 of Set 1 | zhigansk
# Processing Record 579 of Set 1 | ust-nera
# Processing Record 580 of Set 1 | meadow lake
# Processing Record 581 of Set 1 | ostrovnoy
# Processing Record 582 of Set 1 | mbabane
# Processing Record 583 of Set 1 | srednekolymsk
# Processing Record 584 of Set 1 | mackenzie
# Processing Record 585 of Set 1 | damghan
# Processing Record 586 of Set 1 | svatove
# Processing Record 587 of Set 1 | chemal
# Processing Record 588 of Set 1 | lerdo
# Processing Record 589 of Set 1 | barroualie
# City not found. Skipping...
# Processing Record 590 of Set 1 | pavlovka
# Processing Record 591 of Set 1 | ambilobe
# Processing Record 592 of Set 1 | port lincoln
# Processing Record 593 of Set 1 | vardo
# Processing Record 594 of Set 1 | eldorado
# Processing Record 595 of Set 1 | pallapatti
# Processing Record 596 of Set 1 | omsukchan
# Processing Record 597 of Set 1 | tres arroyos
# Processing Record 598 of Set 1 | quatre cocos
# Processing Record 599 of Set 1 | pervomayskiy
# Processing Record 600 of Set 1 | dongsheng
# Processing Record 601 of Set 1 | ilebo
# Processing Record 602 of Set 1 | esperance
# Processing Record 603 of Set 1 | north myrtle beach
# Processing Record 604 of Set 1 | cidreira
# Processing Record 605 of Set 1 | neryungri
# Processing Record 606 of Set 1 | nanga eboko
# Processing Record 607 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 608 of Set 1 | ngaoundere
# Processing Record 609 of Set 1 | benguela
# Processing Record 610 of Set 1 | iskateley
# Processing Record 611 of Set 1 | bandarbeyla
# Processing Record 612 of Set 1 | morkovice-slizany
# City not found. Skipping...
# Processing Record 613 of Set 1 | peniche
# Processing Record 614 of Set 1 | lyubech
# Processing Record 615 of Set 1 | gariaband
# Processing Record 616 of Set 1 | santa catalina
# Processing Record 617 of Set 1 | adrar
# Processing Record 618 of Set 1 | altay
# Processing Record 619 of Set 1 | palu
# Processing Record 620 of Set 1 | hoima
# Processing Record 621 of Set 1 | asosa
# Processing Record 622 of Set 1 | nefteyugansk
# Processing Record 623 of Set 1 | svitavy
# Processing Record 624 of Set 1 | khingansk
# Processing Record 625 of Set 1 | san isidro
# Processing Record 626 of Set 1 | san rafael
# Processing Record 627 of Set 1 | manta
# Processing Record 628 of Set 1 | roanoke rapids
# Processing Record 629 of Set 1 | kobojango
# City not found. Skipping...
# Processing Record 630 of Set 1 | gouyave
# Processing Record 631 of Set 1 | farafangana
# Processing Record 632 of Set 1 | mackay
# Processing Record 633 of Set 1 | fonte boa
# Processing Record 634 of Set 1 | aniva
# Processing Record 635 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 636 of Set 1 | carbonia
# Processing Record 637 of Set 1 | klisura
# Processing Record 638 of Set 1 | baillif
# Processing Record 639 of Set 1 | indramayu
# Processing Record 640 of Set 1 | boa vista
# Processing Record 641 of Set 1 | banon
# Processing Record 642 of Set 1 | nuuk
# Processing Record 643 of Set 1 | erzin
# Processing Record 644 of Set 1 | kruisfontein
# Processing Record 645 of Set 1 | basco
# Processing Record 646 of Set 1 | parit raja
# City not found. Skipping...
# Processing Record 647 of Set 1 | strezhevoy
# Processing Record 648 of Set 1 | xining
# Processing Record 649 of Set 1 | moundsville
# Processing Record 650 of Set 1 | havre-saint-pierre
# Processing Record 651 of Set 1 | coolum beach
# Processing Record 652 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 653 of Set 1 | ladyzhyn
# Processing Record 654 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 655 of Set 1 | kautokeino
# Processing Record 656 of Set 1 | san carlos de bariloche
# Processing Record 657 of Set 1 | rakke
# Processing Record 658 of Set 1 | pipraich
# Processing Record 659 of Set 1 | jalu
# Processing Record 660 of Set 1 | ridgetown
# Processing Record 661 of Set 1 | touba
# Processing Record 662 of Set 1 | banda aceh
# Processing Record 663 of Set 1 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 664 of Set 1 | port hardy
# Processing Record 665 of Set 1 | la ronge
# Processing Record 666 of Set 1 | sabha
# Processing Record 667 of Set 1 | gawler
# Processing Record 668 of Set 1 | chekhov
# Processing Record 669 of Set 1 | saint anthony
# Processing Record 670 of Set 1 | macaracas
# Processing Record 671 of Set 1 | savannah bight
# Processing Record 672 of Set 1 | katha
# City not found. Skipping...
# Processing Record 673 of Set 1 | lata
# Processing Record 674 of Set 1 | kolda
# Processing Record 675 of Set 1 | turukhansk
# Processing Record 676 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 677 of Set 1 | nizwa
# Processing Record 678 of Set 1 | nyurba
# Processing Record 679 of Set 1 | kirovskiy
# Processing Record 680 of Set 1 | koungou
# City not found. Skipping...
# Processing Record 681 of Set 1 | matara
# Processing Record 682 of Set 1 | gimli
# Processing Record 683 of Set 1 | karratha
# Processing Record 684 of Set 1 | yacuiba
# Processing Record 685 of Set 1 | piojo
# City not found. Skipping...
# Processing Record 686 of Set 1 | terra santa
# Processing Record 687 of Set 1 | mahajanga
# Processing Record 688 of Set 1 | esna
# Processing Record 689 of Set 1 | punta de piedra
# Processing Record 690 of Set 1 | kisangani
# Processing Record 691 of Set 1 | beidao
# Processing Record 692 of Set 1 | nusaybin
# Processing Record 693 of Set 1 | candelaria
# Processing Record 694 of Set 1 | chinsali
# Processing Record 695 of Set 1 | mocuba
# Processing Record 696 of Set 1 | harwich
# Processing Record 697 of Set 1 | haimen
# Processing Record 698 of Set 1 | kiomboi
# Processing Record 699 of Set 1 | rodino
# Processing Record 700 of Set 1 | sarkand
# Processing Record 701 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 702 of Set 1 | handwara
# City not found. Skipping...
# Processing Record 703 of Set 1 | vikhorevka
# Processing Record 704 of Set 1 | sault sainte marie
# Processing Record 705 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 706 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 707 of Set 1 | nipawin
# Processing Record 708 of Set 1 | zabaykalsk
# Processing Record 709 of Set 1 | orlik
# Processing Record 710 of Set 1 | palauig
# Processing Record 711 of Set 1 | mayumba
# Processing Record 712 of Set 1 | esmeraldas
# Processing Record 713 of Set 1 | santa rosa
# Processing Record 714 of Set 1 | challapata
# Processing Record 715 of Set 1 | garowe
# Processing Record 716 of Set 1 | riaba
# City not found. Skipping...
# Processing Record 717 of Set 1 | cabra
# Processing Record 718 of Set 1 | gazanjyk
# Processing Record 719 of Set 1 | maturin
# Processing Record 720 of Set 1 | camacha
# Processing Record 721 of Set 1 | junction city
# Processing Record 722 of Set 1 | seymchan
# Processing Record 723 of Set 1 | palagonia
# Processing Record 724 of Set 1 | barlinek
# Processing Record 725 of Set 1 | bucak
# Processing Record 726 of Set 1 | dudinka
# Processing Record 727 of Set 1 | luorong
# Processing Record 728 of Set 1 | zyryanka
# Processing Record 729 of Set 1 | prince george
# Processing Record 730 of Set 1 | buala
# Processing Record 731 of Set 1 | kostomuksha
# Processing Record 732 of Set 1 | miles city
# Processing Record 733 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 734 of Set 1 | antofagasta
# Processing Record 735 of Set 1 | mombetsu
# Processing Record 736 of Set 1 | barra do corda
# Processing Record 737 of Set 1 | ginir
# Processing Record 738 of Set 1 | omboue
# Processing Record 739 of Set 1 | uvira
# Processing Record 740 of Set 1 | esfarayen
# Processing Record 741 of Set 1 | huarmey
# Processing Record 742 of Set 1 | tabatinga
# Processing Record 743 of Set 1 | vinh long
# Processing Record 744 of Set 1 | luwuk
# Processing Record 745 of Set 1 | heihe
# Processing Record 746 of Set 1 | pangkalanbuun
# Processing Record 747 of Set 1 | havelock
# Processing Record 748 of Set 1 | broken hill
# Processing Record 749 of Set 1 | coari
# Processing Record 750 of Set 1 | dana point
# Processing Record 751 of Set 1 | fayaoue
# Processing Record 752 of Set 1 | north bend
# Processing Record 753 of Set 1 | macas
# Processing Record 754 of Set 1 | puerto leguizamo
# Processing Record 755 of Set 1 | onverwacht
# Processing Record 756 of Set 1 | maarianhamina
# City not found. Skipping...
# Processing Record 757 of Set 1 | vestmanna
# Processing Record 758 of Set 1 | hovd
# Processing Record 759 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 760 of Set 1 | qafsah
# City not found. Skipping...
# Processing Record 761 of Set 1 | muisne
# Processing Record 762 of Set 1 | tilichiki
# Processing Record 763 of Set 1 | nchelenge
# Processing Record 764 of Set 1 | clonakilty
# Processing Record 765 of Set 1 | flin flon
# Processing Record 766 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 767 of Set 1 | hokitika
# Processing Record 768 of Set 1 | kailua
# Processing Record 769 of Set 1 | opelousas
# Processing Record 770 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 771 of Set 1 | pecos
# Processing Record 772 of Set 1 | batagay-alyta
# Processing Record 773 of Set 1 | naryan-mar
# Processing Record 774 of Set 1 | baruun-urt
# Processing Record 775 of Set 1 | le port
# Processing Record 776 of Set 1 | yeletskiy
# City not found. Skipping...
# Processing Record 777 of Set 1 | outjo
# Processing Record 778 of Set 1 | brownsville
# Processing Record 779 of Set 1 | sola
# Processing Record 780 of Set 1 | descalvado
# Processing Record 781 of Set 1 | sioux lookout
# Processing Record 782 of Set 1 | chegem
# Processing Record 783 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 784 of Set 1 | alindao
# Processing Record 785 of Set 1 | pesochnoye
# Processing Record 786 of Set 1 | kattivakkam
# Processing Record 787 of Set 1 | padang
# Processing Record 788 of Set 1 | kobryn
# Processing Record 789 of Set 1 | oistins
# Processing Record 790 of Set 1 | suzu
# City not found. Skipping...
# Processing Record 791 of Set 1 | vila
# Processing Record 792 of Set 1 | medicine hat
# Processing Record 793 of Set 1 | kousseri
# City not found. Skipping...
# Processing Record 794 of Set 1 | teahupoo
# Processing Record 795 of Set 1 | barstow
# Processing Record 796 of Set 1 | torres
# Processing Record 797 of Set 1 | tecoanapa
# Processing Record 798 of Set 1 | portlethen
# Processing Record 799 of Set 1 | russell
# Processing Record 800 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 801 of Set 1 | petrolina
# Processing Record 802 of Set 1 | chernyshevskiy
# Processing Record 803 of Set 1 | plettenberg bay
# Processing Record 804 of Set 1 | mossendjo
# Processing Record 805 of Set 1 | bambanglipuro
# Processing Record 806 of Set 1 | kinablangan
# Processing Record 807 of Set 1 | dabakala
# Processing Record 808 of Set 1 | vetralla
# Processing Record 809 of Set 1 | champerico
# Processing Record 810 of Set 1 | diamantino
# Processing Record 811 of Set 1 | devonport
# Processing Record 812 of Set 1 | sorong
# Processing Record 813 of Set 1 | florence
# Processing Record 814 of Set 1 | non thai
# Processing Record 815 of Set 1 | calvia
# Processing Record 816 of Set 1 | odemira
# Processing Record 817 of Set 1 | troitskoye
# Processing Record 818 of Set 1 | conde
# Processing Record 819 of Set 1 | kalanguy
# Processing Record 820 of Set 1 | corpus christi
# Processing Record 821 of Set 1 | homer
# Processing Record 822 of Set 1 | mundo novo
# Processing Record 823 of Set 1 | kieta
# Processing Record 824 of Set 1 | samarai
# Processing Record 825 of Set 1 | caucaia
# Processing Record 826 of Set 1 | iquique
# Processing Record 827 of Set 1 | labuhan
# Processing Record 828 of Set 1 | sakaraha
# Processing Record 829 of Set 1 | boende
# Processing Record 830 of Set 1 | auki
# Processing Record 831 of Set 1 | moanda
# Processing Record 832 of Set 1 | barcelos
# Processing Record 833 of Set 1 | margherita
# Processing Record 834 of Set 1 | alta floresta
# Processing Record 835 of Set 1 | vung tau
# Processing Record 836 of Set 1 | arlit
# Processing Record 837 of Set 1 | hindupur
# Processing Record 838 of Set 1 | maceio
# Processing Record 839 of Set 1 | bolshaya glushitsa
# Processing Record 840 of Set 1 | salinas
# Processing Record 841 of Set 1 | laichingen
# Processing Record 842 of Set 1 | virginia beach
# Processing Record 843 of Set 1 | shenjiamen
# Processing Record 844 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 845 of Set 1 | luanda
# Processing Record 846 of Set 1 | ximei
# Processing Record 847 of Set 1 | saravan
# Processing Record 848 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 849 of Set 1 | puerto carreno
# Processing Record 850 of Set 1 | coahuayana
# Processing Record 851 of Set 1 | beira
# Processing Record 852 of Set 1 | parabel
# Processing Record 853 of Set 1 | yeniseysk
# Processing Record 854 of Set 1 | hit
# Processing Record 855 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 856 of Set 1 | erdaojiang
# Processing Record 857 of Set 1 | ancud
# Processing Record 858 of Set 1 | lubbock
# Processing Record 859 of Set 1 | cananea
# Processing Record 860 of Set 1 | karonga
# Processing Record 861 of Set 1 | dawson creek
# Processing Record 862 of Set 1 | tripoli
# Processing Record 863 of Set 1 | yzeure
# Processing Record 864 of Set 1 | zaozerne
# Processing Record 865 of Set 1 | nuevo progreso
# Processing Record 866 of Set 1 | pugo
# Processing Record 867 of Set 1 | tahta
# City not found. Skipping...
# Processing Record 868 of Set 1 | am timan
# Processing Record 869 of Set 1 | tautira
# Processing Record 870 of Set 1 | la rioja
# Processing Record 871 of Set 1 | singaraja
# Processing Record 872 of Set 1 | sinnamary
# Processing Record 873 of Set 1 | mahibadhoo
# Processing Record 874 of Set 1 | quang ngai
# Processing Record 875 of Set 1 | cheney
# Processing Record 876 of Set 1 | chateau-gontier
# Processing Record 877 of Set 1 | porto santo
# City not found. Skipping...
# Processing Record 878 of Set 1 | ryotsu
# Processing Record 879 of Set 1 | altar
# Processing Record 880 of Set 1 | nabire
# Processing Record 881 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 882 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 883 of Set 1 | lajoskomarom
# Processing Record 884 of Set 1 | leninskiy
# Processing Record 885 of Set 1 | polewali
# Processing Record 886 of Set 1 | demir hisar
# Processing Record 887 of Set 1 | anahuac
# Processing Record 888 of Set 1 | aksarka
# Processing Record 889 of Set 1 | bermejo
# Processing Record 890 of Set 1 | ulladulla
# Processing Record 891 of Set 1 | nosy varika
# Processing Record 892 of Set 1 | southbridge
# Processing Record 893 of Set 1 | trinidad

# %%
weather_df.head()
# Out:
#              City Country    Lat     Lng        Date Temperature  \
# 0      rio grande      BR -32.03   -52.1  1572401027      292.13
# 1         salalah      OM  17.01    54.1  1572401030      298.15
# 2  saint-philippe      CA  45.36  -73.48  1572400997      285.19
# 3       busselton      AU -33.64  115.35  1572401030      291.27
# 4    saint george      GR  39.45   22.34  1572401030      282.95
#
#   Max_Temperature Min_Temperature Humidity Cloudiness Wind Speed
# 0          292.13          292.13       93        100       6.07
# 1          298.15          298.15       50         95        2.1
# 2          286.15          283.71       81          1        5.7
# 3          293.15          289.82       49         59      12.36
# 4          284.15          282.15       81          0        2.6

# %%
exportweather = weather_df.to_csv(r"weather_data.csv", index=None, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max_Temperature"], marker="o")

d = datetime.datetime.today()

# Incorporate the other graph properties
title = 'City Latitude vs. Max Temperature ('+ str(d.month) +'/' + str(d.day)+'/' + str(d.year)+')'
plt.title(title)
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureandLatitudes.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for humidy and latitude
plt.scatter(weather_df["Lat"],weather_df["Humidity"],  marker="o")

# Incorporate the other graph properties
title = 'City Latitude vs. Humidity ('+ str(d.month) +'/' + str(d.day)+'/' + str(d.year)+')'
plt.title(title)
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityandLatitudes.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Cloudiness and latitude
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
title = 'City Latitude vs. Cloudiness ('+ str(d.month) +'/' + str(d.day)+'/' + str(d.year)+')'
plt.title(title)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessandLatitudes.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Cloudiness and latitude
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
title = 'City Latitude vs. Cloudiness ('+ str(d.month) +'/' + str(d.day)+'/' + str(d.year)+')'
plt.title(title)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessandLatitudes.png")

# Show plot
plt.show()
